# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, brier_score_loss, confusion_matrix, classification_report
from sklearn.calibration import CalibrationDisplay, CalibratedClassifierCV

plt.rcParams['figure.figsize'] = (5,4)

# %%
sales = pd.read_csv('../data/raw/ventas_backtesting_new.csv')
products = pd.read_csv('../data/raw/productos.csv')
products.rename(columns={'codigo_unico': 'product'}, inplace=True)
pred = pd.read_csv('../predictions/predicciones.csv')
# Out:
# /var/folders/1g/77kw2x4j5678s_87_sqc1fpc0000gp/T/ipykernel_33124/1114700142.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('../data/raw/ventas_backtesting_new.csv')

# %%
df = pd.merge(sales,products,how='left',on='product')

# %%
df[df["identification_doct"] == '1003404385']["description"].unique()
# Out:
# array(['PONY MALTA MINI PET  x 200ML',
#        'PASTEL JAMON QUESO MULTIPAN *100GR',
#        'LECHE UHT DESLACTOSADA EUROMAX x 900ML',
#        'SALCHICHA TIPO ASADO QUALITY BEEF*500GR',
#        'PONY MALTA MINI PET 6U x 200ML', 'JUGO NATURAL X 12 OZ MENU',
#        'SOPA CON HUESO CARNAVAL'], dtype=object)

# %%
pred[pred["client"] == 1003404385]["description"].unique()
# Out:
# array(['PONY MALTA PET  x 330ML', 'AGUA CRISTAL ECOPACK  x 1000ML',
#        'GASEOSA COLOMBIA ROCOLA X 400ML',
#        'MOLLEJAS REFRIGERADOS A GRANEL',
#        'GASEOSA COLA NEGRA ROCOLA X 400ML'], dtype=object)
